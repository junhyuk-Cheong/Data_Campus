# %% [markdown]
# # 데이터 시각화 (Matplotlib) 활용와 왕좌의 게임 데이터 분석

# %% [markdown]
# ## 1. matplotlib 간단 실습

# %% [markdown]
# ### 1.1 하나의 그래프 그리기
# 1.1.1 line graph 그리기

# %%
import matplotlib.pyplot as plt

# %%
sr = Series([10, 25, 35, 15, 23], index = ['a', 'b', 'c', 'd','e'])

# %%
sr
# Out:
# a    10
# b    25
# c    35
# d    15
# e    23
# dtype: int64

# %%
#plt.plot(sr)

fig, ax = plt.subplots()
ax.plot(sr)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a, b = [1,2]

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %% [markdown]
# 1.1.2 bar graph 그리기

# %%
import random
sr2 = Series(random.sample(range(100, 1000),5), index = ['a', 'b', 'c', 'd', 'e'])

# %%
sr2
# Out:
# a    853
# b    520
# c    835
# d    371
# e    279
# dtype: int64

# %%
plt.bar(sr2.index, sr2.values, width = 0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
sr2.plot(kind = 'line')
# Out:
# <AxesSubplot:>

# %%
sr2.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1.1.3 두 개의 그래프를 하나로 그리기
#
# - <a href = https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.subplots.html> plt.subplots() </a> 함수는 새로운 figure와 axes(subplots)를 생성해 준다.

# %%
fig, ax = plt.subplots()
ax.plot(sr, color='r')
ax.bar(sr2.index, sr2.values)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %% [markdown]
# 1.1.4 두 개 그래프를 서로 다른 y축 적용하기

# %%
fig, ax = plt.subplots()
ax.plot(sr, color='r')
ax2 = ax.twinx()
ax2.bar(sr2.index, sr2.values, alpha = 0.3)
# 그래프 제목 부여
ax.set_title('Graph #1')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Graph #1')

# %% [markdown]
# ### 1.2. 여러 개 그래프 그리기
# 하나의 figure 안에 여러 개의 axes를 그리기

# %%
fig, ax_list = plt.subplots(2, 2)
ax_list[0, 0].plot(sr)
ax_list[0, 0].set_title('Axes #1')
ax_list[0, 0].set_xlabel('x1')
ax_list[0, 0].set_ylabel('y1')
ax_list[0, 1].bar(sr2.index, sr2.values, alpha = 0.3, color ='r')
ax_list[1, 0].hist(random.sample(range(1, 100), 50))
ax_list[1, 1].scatter(random.sample(range(1, 100), 99), random.sample(range(1, 100), 99), alpha = 0.3)

#fig.subplots_adjust(hspace = 0.5, wspace = 0.5)
plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %% [markdown]
# ### 1.3. <a href = https://matplotlib.org/3.1.1/tutorials/introductory/usage.html#what-is-a-backend> backend </a> 개념
# Matplotlib은 매우 다양한 usecase에 사용되며, 이를 모두 충족시키기 위하여 다양한 backend를 지원함.
# 가장 많이 활용하는 옵션은 inline으로, 그래프를 output창에 바로 표현되도록 하는 옵션이며, <strong>%maptlotlib inline</strong>를 실행하여 설정한다.
#
#
# %로 시작하는 명령어는 Cell Magic 명령어로써, 파이썬 코드가 아니라 Jupyter에게 특정 기능을 수행하도록 하는 명령이다. 즉, %matplotlib inline 명령은 Jupyter에게 matplotlib 그래프를 출력 영역에 표시할 것을 지시하는 명령이다.

# %% [markdown]
# 만약 그래프를 생성한 이후, interactive하게 그래프를 다루고 싶은 경우에는 backend를 interactive backend로 설정하면 된다.
# 예를 들어, <strong>%matplotlib nbagg</strong>를 실행하여 <strong>nbagg</strong>으로 설정을 변경할 수 있다.
# 보다 다양한 설정 옵션을 확인하려면 <a href = https://matplotlib.org/3.1.1/tutorials/introductory/usage.html#what-is-a-backend> 여기 </a>를 참고하면 된다.
#
# 아래와 같이 nbagg로 설정한 후, 그래프를 생성하면 output 창에 몇몇 버튼과 함께 그래프가 그려진다.
# 버튼들을 활용하여 zoon-in, zoom-out이 가능하다.
# 그래프를 그린 이후, set_title(), set_xlabel() 함수를 수행하면 현재 그래프에 적용되는 것을 확인할 수 있으며, 오른쪽 상단에 있는 파란색 버튼을 클릭하면 interactive 모드가 종료된다.

# %%
# %matplotlib nbagg

# %%
fig, ax = plt.subplots()
ax.plot(sr)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_title('Axes #1')
# Out:
# Text(0.5, 1.0, 'Axes #1')

# %%
ax.bar(sr2.index, sr2.values, color ='r', alpha = 0.5)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### 1.4 <a href = https://matplotlib.org/users/customizing.html> matplotlib 설정 변경</a>
#
# <strong> 1.4.1 stylesheet 변경</strong>
#    matplotlib을 통해 데이터 시각화할 때 적용되는 스타일을 변경 가능하며, 사용가능한 스타일시트 목록 및 샘플은 <a href= https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html> 여기 </a>에서 확인 가능하다.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# %matplotlib inline

# %%
plt.style.use('ggplot')
plt.plot(sr)

# %%
plt.style.use('ggplot')
plt.plot(sr)

# %% [markdown]
# 1.4.2 <strong> <i> matplotlibrc</i></strong> 파일 수정을 통한 파라미터 수정
# - matplotlibrc 파일을 통해 figure 크기, axes의 폰트사이즈, 색상, 스타일 등 matplotlib의 모든 속성(property)들을 설정 가능하다.
# - 파일을 변경한 후 저장하면, 이후에는 변경된 설정이 계속 사용된다.
# - matplotlibrc 파일을 수정한 후에는 jupyter notebook을 재시작해야 수정 내용이 반영된다.

# %% [markdown]
# matplotlibrc 파일의 위치를 찾으려면 matplotlib.matplot.lib_fname()를 수행하면 된다.

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %% [markdown]
# 1.4.3 matplotlib.rcParams을 통한 동적 설정 변경
#
# - matplotlib의 설정 정보는 <strong> matplotlib.rcParams</strong>에 저장되어 있으며, rcParams는 <strong><i>사전(Dict)</i></strong> 타입니다.
# - rcParams 변경을 통해 동적으로 설정이 변경가능하며, 변경 즉시 반영된다.

# %%
matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# %%
sr3 = Series([10, 20, 30], index = ['가', '나', '다'])

# %%
plt.plot(sr3)

# %% [markdown]
# ## 2. <a href=https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html>Pandas의 plot() 함수를 통한 시각화</a>
# - pandas의 대표적인 데이터타입인 Series와 DataFrame은 plot() 함수를 제공하며 이를 통해 여러 차트를 그릴 수 있다.
# - 내부적으로는 Series.plot()과 DataFrame.plot() 모두 matplotlib를 사용하며, 파라미터 인자에 따라 적절한 함수가 호출된다.
# - matplotlib은 plot()은 line graph, bar()는 bar graph, hist()는 히스토그램 등 차트의 종류에 따라 다른 함수를 호출해야 하지만, pandas는 차트의 종류에 상관 없이, 차트를 그리는 함수는 plot()이며, kind 인자를 통해 차트의 종류를 설정할 수 있다.
# - matplotlib의 함수들을 직접 사용하는 것보다 사용자 친화적인 인터페이스를 제공하지만, matplotlib의 모든 기능을 제공하지는 않으므로 약간의 불편함은 존재한다.

# %%
인구통계 = {'서울': [1053.5, 1023, 987],
        '경기':[1023, 1067, 1123],
        '충청':[512,489,487],
        '경상':[897, 872, 811],
        '전라':[451, 421, 399]
      }
df = DataFrame(인구통계)
df.index = [2018, 2019, 2020]

# %%
df
# Out:
#           서울    경기   충청   경상   전라
# 2018  1053.5  1023  512  897  451
# 2019  1023.0  1067  489  872  421
# 2020   987.0  1123  487  811  399

# %%
plt.plot(df)

# %%
matplotlib.style.use('ggplot')

# %%
df.plot(kind = 'line', title = '인구추이', figsize = (5,3), subplots = False,
       xticks = [2018,2019,2020])
# Out:
# <AxesSubplot:title={'center':'인구추이'}>

# %%
df.plot(kind = 'line', title = '인구추이', figsize = (5,3), subplots = False,
       xticks = df.index, ylim = [0, 1500],
       xlabel = '연도',
       ylabel = '인구수')
# Out:
# <AxesSubplot:title={'center':'인구추이'}, xlabel='연도', ylabel='인구수'>

# %%
df.plot(kind = 'line', title = '인구추이', figsize = (5,3), subplots = False,
       xticks = df.index, ylim = [0, 1500],
       xlabel = '연도',
       ylabel = '인구수',
       style = ['bo-', 'b--', 'd-', 'o-', '<-'],
       lw = 3)
# Out:
# <AxesSubplot:title={'center':'인구추이'}, xlabel='연도', ylabel='인구수'>

# %% [markdown]
# 기본 그리기 - <a href= https://matplotlib.org/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D>line graph</a>

# %% [markdown]
# <img src="img/예제실습/matplotlib인자.jpg" alt=" matplotlib" style="width: 1200px;"/>
#
# #### 색상: https://matplotlib.org/examples/color/named_colors.html
# #### 기타 스타일: https://matplotlib.org/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D

# %%
# 실습. 연도별 지역별 인구수 그래프 그리기

# %%
df.T.plot(kind = 'bar', subplots = True)
# Out:
# array([<AxesSubplot:title={'center':'2018'}>,
#        <AxesSubplot:title={'center':'2019'}>,
#        <AxesSubplot:title={'center':'2020'}>], dtype=object)

# %%
df2 = df.reset_index()

# %%
df2
# Out:
#    index      서울    경기   충청   경상   전라
# 0   2018  1053.5  1023  512  897  451
# 1   2019  1023.0  1067  489  872  421
# 2   2020   987.0  1123  487  811  399

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot(x = 'index')
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df2.plot(x = 'index', y = ['서울', '경기', '충청', '경상', '전라'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df2.plot(x = 'index', y = ['서울', '경기'])
# Out:
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# ## 3. 왕좌의 게임 데이터 분석 및 시각화 실습
# #### 1) 데이터 적재
# - battless.csv : 전투의 이름, 발생년도, 공격/수비 정보(가문, 왕, 군대 규모 등)을 저장
# - deaths.csv : 캐릭터들의 이름, 성별 등 기본 정보와 사망 정보

# %%
battles = pd.read_csv('data/data-society-game-of-thrones/battles.csv')
death = pd.read_csv('data/data-society-game-of-thrones/character-deaths.csv')

# %%
battles.head(3)
# Out:
#                           name  year  battle_number             attacker_king  \
# 0   Battle of the Golden Tooth   298              1  Joffrey/Tommen Baratheon
# 1  Battle at the Mummer's Ford   298              2  Joffrey/Tommen Baratheon
# 2           Battle of Riverrun   298              3  Joffrey/Tommen Baratheon
#
#   defender_king attacker_1 attacker_2 attacker_3 attacker_4 defender_1  ...  \
# 0    Robb Stark  Lannister        NaN        NaN        NaN      Tully  ...
# 1    Robb Stark  Lannister        NaN        NaN        NaN  Baratheon  ...
# 2    Robb Stark  Lannister        NaN        NaN        NaN      Tully  ...
#
#   major_death  major_capture  attacker_size defender_size  \
# 0         1.0            0.0        15000.0        4000.0
# 1         1.0            0.0            NaN         120.0
# 2         0.0            1.0        15000.0       10000.0
#
#              attacker_commander             defender_commander  summer  \
# ...

# %%
death.head(3)
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
#
#    DwD
# 0    0
# 1    0
# 2    1

# %% [markdown]
# #### 2) 책의 권(Book of Death)별로 사망자 수 추이 시각화

# %%
death['Book of Death']
# Out:
# 0      NaN
# 1      3.0
# 2      NaN
# 3      5.0
# 4      NaN
#       ...
# 912    NaN
# 913    5.0
# 914    5.0
# 915    5.0
# 916    4.0
# Name: Book of Death, Length: 917, dtype: float64

# %%
bookofDeath = death.value_counts('Book of Death').sort_index()

# %%
bookofDeath
# Out:
# Book of Death
# 1.0    49
# 2.0    73
# 3.0    97
# 4.0    27
# 5.0    61
# dtype: int64

# %%
axes = bookofDeath.plot(xticks = bookofDeath.index,
                       ylim = [0, 100],
                       xlabel = '권',
                       ylabel = '사망자수',
                       title = '권별 사망자수 추이')

# %%
axes
# Out:
# <AxesSubplot:title={'center':'권별 사망자수 추이'}, xlabel='권', ylabel='사망자수'>

# %%
axes.savefig('test.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-2b26eef86ac9> in <module>
# ----> 1 axes.savefig('test.jpg')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
axes.figure.savefig('test.jpg')

# %% [markdown]
# #### 3) 대규모 전투의  공격진영과 수비 진영의 숫자 시각화
# 대규모 전투 = 공격과 수비 모두 합쳐서 10,000명 이상 참가한 전쟁

# %%
################################ 나의 풀이 ####################################

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battles['attacker_size']
# Out:
# 0      15000.0
# 1          NaN
# 2      15000.0
# 3      18000.0
# 4       1875.0
# 5       6000.0
# 6          NaN
# 7          NaN
# 8       1000.0
# 9        264.0
# 10       244.0
# 11        20.0
# 12         NaN
# 13       618.0
# 14      6000.0
# 15      5000.0
# 16     20000.0
# 17       100.0
# 18      6000.0
# 19     21000.0
# 20         NaN
# 21      3000.0
# 22         NaN
# 23         NaN
# 24         NaN
# 25      3500.0
# 26         NaN
# 27    100000.0
# 28         NaN
# 29         NaN
# 30      4500.0
# 31         NaN
# 32         NaN
# 33         NaN
# 34      2000.0
# 35      3000.0
# 36      1500.0
# 37      5000.0
# Name: attacker_size, dtype: float64

# %%
battle = battles[battles['attacker_size']  + battles['defender_size'] >= 10000]

# %%
battle
# Out:
#                           name  year  battle_number             attacker_king  \
# 0   Battle of the Golden Tooth   298              1  Joffrey/Tommen Baratheon
# 2           Battle of Riverrun   298              3  Joffrey/Tommen Baratheon
# 3     Battle of the Green Fork   298              4                Robb Stark
# 5          Battle of the Camps   298              6                Robb Stark
# 14           Battle of Oxcross   299             15                Robb Stark
# 15        Siege of Storm's End   299             16         Stannis Baratheon
# 16         Battle of the Fords   299             17  Joffrey/Tommen Baratheon
# 19    Battle of the Blackwater   299             20         Stannis Baratheon
# 27      Battle of Castle Black   300             28         Stannis Baratheon
# 37         Siege of Winterfell   300             38         Stannis Baratheon
#
#                defender_king attacker_1 attacker_2 attacker_3 attacker_4  \
# ...

# %%
battle = battle.set_index('name')

# %%
battle
# Out:
#                             year  battle_number             attacker_king  \
# name
# Battle of the Golden Tooth   298              1  Joffrey/Tommen Baratheon
# Battle of Riverrun           298              3  Joffrey/Tommen Baratheon
# Battle of the Green Fork     298              4                Robb Stark
# Battle of the Camps          298              6                Robb Stark
# Battle of Oxcross            299             15                Robb Stark
# Siege of Storm's End         299             16         Stannis Baratheon
# Battle of the Fords          299             17  Joffrey/Tommen Baratheon
# Battle of the Blackwater     299             20         Stannis Baratheon
# Battle of Castle Black       300             28         Stannis Baratheon
# Siege of Winterfell          300             38         Stannis Baratheon
#
#                                        defender_king attacker_1 attacker_2  \
# name
# ...

# %%
battle.plot(kind = 'bar', y = ['attacker_size', 'defender_size'], figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='name'>

# %%
############################# 강사님 풀이 ########################################

# %%
#1. 대규모 전투만 선택

# %%
big_battles = battles[battles.attacker_size + battles.defender_size >= 1000]

# %%
big_battles
# Out:
#                              name  year  battle_number  \
# 0      Battle of the Golden Tooth   298              1
# 2              Battle of Riverrun   298              3
# 3        Battle of the Green Fork   298              4
# 4   Battle of the Whispering Wood   298              5
# 5             Battle of the Camps   298              6
# 10     Battle of Torrhen's Square   299             11
# 13             Sack of Winterfell   299             14
# 14              Battle of Oxcross   299             15
# 15           Siege of Storm's End   299             16
# 16            Battle of the Fords   299             17
# 19       Battle of the Blackwater   299             20
# 25                The Red Wedding   299             26
# 27         Battle of Castle Black   300             28
# 30     Retaking of Deepwood Motte   300             31
# 37            Siege of Winterfell   300             38
#
#                attacker_king             defender_king attacker_1 attacker_2  \
# ...

# %%
#2. 필요한 컬럼만 선택
big_battles = big_battles[['name', 'attacker_size', 'defender_size']]

# %%
big_battles
# Out:
#                              name  attacker_size  defender_size
# 0      Battle of the Golden Tooth        15000.0         4000.0
# 2              Battle of Riverrun        15000.0        10000.0
# 3        Battle of the Green Fork        18000.0        20000.0
# 4   Battle of the Whispering Wood         1875.0         6000.0
# 5             Battle of the Camps         6000.0        12625.0
# 10     Battle of Torrhen's Square          244.0          900.0
# 13             Sack of Winterfell          618.0         2000.0
# 14              Battle of Oxcross         6000.0        10000.0
# 15           Siege of Storm's End         5000.0        20000.0
# 16            Battle of the Fords        20000.0        10000.0
# 19       Battle of the Blackwater        21000.0         7250.0
# 25                The Red Wedding         3500.0         3500.0
# 27         Battle of Castle Black       100000.0         1240.0
# 30     Retaking of Deepwood Motte         4500.0          200.0
# ...

# %%
#3. 시각화
big_battles.plot(kind = 'barh', x = 'name',
                    stacked = True)
# Out:
# <AxesSubplot:ylabel='name'>

# %% [markdown]
# #### 4) (실습 #1) 가문 별로 전쟁을 참여한 횟수 시각화

# %%
############################# 나의 풀이 ################################

# %%
battles.columns
# attacker_1 ~ defender_4
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
battles
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battles.attacker_2.value_counts()
# Out:
# Tully        3
# Karstark     2
# Thenns       1
# Greyjoy      1
# Frey         1
# Lannister    1
# Bolton       1
# Name: attacker_2, dtype: int64

# %%
battles.attacker_1.value_counts()
# Out:
# Lannister                      8
# Stark                          8
# Greyjoy                        7
# Baratheon                      6
# Frey                           2
# Bolton                         2
# Brotherhood without Banners    1
# Free folk                      1
# Darry                          1
# Bracken                        1
# Brave Companions               1
# Name: attacker_1, dtype: int64

# %%
battles.attacker_1.value_counts().add(battles.attacker_2.value_counts(), fill_value = 0)
# Out:
# Baratheon                      6.0
# Bolton                         3.0
# Bracken                        1.0
# Brave Companions               1.0
# Brotherhood without Banners    1.0
# Darry                          1.0
# Free folk                      1.0
# Frey                           3.0
# Greyjoy                        8.0
# Karstark                       2.0
# Lannister                      9.0
# Stark                          8.0
# Thenns                         1.0
# Tully                          3.0
# dtype: float64

# %%
battle2 = pd.DataFrame()

# %%
battle2 = battles.attacker_1.value_counts().add(battles.attacker_2.value_counts(), fill_value = 0)

# %%
battle2
# Out:
# Baratheon                      6.0
# Bolton                         3.0
# Bracken                        1.0
# Brave Companions               1.0
# Brotherhood without Banners    1.0
# Darry                          1.0
# Free folk                      1.0
# Frey                           3.0
# Greyjoy                        8.0
# Karstark                       2.0
# Lannister                      9.0
# Stark                          8.0
# Thenns                         1.0
# Tully                          3.0
# dtype: float64

# %%
battles.columns[5]
# Out:
# 'attacker_1'

# %%
battles.columns[12]
# Out:
# 'defender_4'

# %%
for i in range(7, 13):
    battle2 = battle2.add(battles[battles.columns[i]].value_counts(), fill_value = 0)

# %%
battle2
# Out:
# Baratheon                      11.0
# Blackwood                       1.0
# Bolton                          4.0
# Bracken                         1.0
# Brave Companions                3.0
# Brotherhood without Banners     1.0
# Darry                           2.0
# Free folk                       1.0
# Frey                            4.0
# Giants                          1.0
# Glover                          2.0
# Greyjoy                        11.0
# Karstark                        2.0
# Lannister                      18.0
# Mallister                       1.0
# Mormont                         2.0
# Night's Watch                   1.0
# Stark                          16.0
# Thenns                          1.0
# Tully                           7.0
# Tyrell                          2.0
# dtype: float64

# %%
battle2.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
##################### 강사님 풀이 ##########################

# %%
#1. 필요한 칼럼만 선택
# attacker_1 ~ defender_4 총 8개 컬럼
#1
# battles[['attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1', 'defender_2', 'defender_3', 'defender_4']]
#2 컬럼을 슬라이싱
# battles.loc[:, 'attacker_1':'defender_4']

#3. 슬라이싱의 또다른 방법
# battles[battles.columns[5:13]]

#4. 정규표현식을 사용
battle_house = battles.filter(regex = 'attacker_[1-4]|defender_[1-4]')

# %%
#각 가문들이 출현한 회수를 집계
battle_house.attacker_1.value_counts().add(battle_house.attacker_2.value_counts(), fill_value = 0)
# Out:
# Baratheon                      6.0
# Bolton                         3.0
# Bracken                        1.0
# Brave Companions               1.0
# Brotherhood without Banners    1.0
# Darry                          1.0
# Free folk                      1.0
# Frey                           3.0
# Greyjoy                        8.0
# Karstark                       2.0
# Lannister                      9.0
# Stark                          8.0
# Thenns                         1.0
# Tully                          3.0
# dtype: float64

# %%
house_to_battle_count = Series()
# Out:
# <ipython-input-399-b5c4c60be62f>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   house_to_battle_count = Series()

# %%
for col in battle_house.columns:
    house_to_battle_count = house_to_battle_count.add(battle_house[col].value_counts(), fill_value = 0)

# %%
house_to_battle_count
# Out:
# Baratheon                      11.0
# Blackwood                       1.0
# Bolton                          4.0
# Bracken                         1.0
# Brave Companions                3.0
# Brotherhood without Banners     1.0
# Darry                           2.0
# Free folk                       1.0
# Frey                            4.0
# Giants                          1.0
# Glover                          2.0
# Greyjoy                        11.0
# Karstark                        2.0
# Lannister                      18.0
# Mallister                       1.0
# Mormont                         2.0
# Night's Watch                   1.0
# Stark                          16.0
# Thenns                          1.0
# Tully                           7.0
# Tyrell                          2.0
# dtype: float64

# %%
house_to_battle_count.sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 5) (실습 #2) 년도별로 사망자의 숫자와 전쟁이 벌어진 횟수 시각화

# %%
battles.head(3)
# Out:
#                           name  year  battle_number             attacker_king  \
# 0   Battle of the Golden Tooth   298              1  Joffrey/Tommen Baratheon
# 1  Battle at the Mummer's Ford   298              2  Joffrey/Tommen Baratheon
# 2           Battle of Riverrun   298              3  Joffrey/Tommen Baratheon
#
#   defender_king attacker_1 attacker_2 attacker_3 attacker_4 defender_1  ...  \
# 0    Robb Stark  Lannister        NaN        NaN        NaN      Tully  ...
# 1    Robb Stark  Lannister        NaN        NaN        NaN  Baratheon  ...
# 2    Robb Stark  Lannister        NaN        NaN        NaN      Tully  ...
#
#   major_death  major_capture  attacker_size defender_size  \
# 0         1.0            0.0        15000.0        4000.0
# 1         1.0            0.0            NaN         120.0
# 2         0.0            1.0        15000.0       10000.0
#
#              attacker_commander             defender_commander  summer  \
# ...

# %%
battle1 = battles.set_index('name')

# %%
death.set_index('Name')
# Out:
#                              Allegiances  Death Year  Book of Death  \
# Name
# Addam Marbrand                 Lannister         NaN            NaN
# Aegon Frey (Jinglebell)             None       299.0            3.0
# Aegon Targaryen          House Targaryen         NaN            NaN
# Adrack Humble              House Greyjoy       300.0            5.0
# Aemon Costayne                 Lannister         NaN            NaN
# ...                                  ...         ...            ...
# Zollo                               None         NaN            NaN
# Yurkhaz zo Yunzak                   None       300.0            5.0
# Yezzan Zo Qaggaz                    None       300.0            5.0
# Torwynd the Tame                Wildling       300.0            5.0
# Talbert Serry                     Tyrell       300.0            4.0
#
#                          Death Chapter  Book Intro Chapter  Gender  Nobility  \
# Name
# ...

# %%
death1.index.set_names('name', inplace = True)

# %%
death1
# Out:
#                              Allegiances  Death Year  Book of Death  \
# name
# Addam Marbrand                 Lannister         NaN            NaN
# Aegon Frey (Jinglebell)             None       299.0            3.0
# Aegon Targaryen          House Targaryen         NaN            NaN
# Adrack Humble              House Greyjoy       300.0            5.0
# Aemon Costayne                 Lannister         NaN            NaN
# ...                                  ...         ...            ...
# Zollo                               None         NaN            NaN
# Yurkhaz zo Yunzak                   None       300.0            5.0
# Yezzan Zo Qaggaz                    None       300.0            5.0
# Torwynd the Tame                Wildling       300.0            5.0
# Talbert Serry                     Tyrell       300.0            4.0
#
#                          Death Chapter  Book Intro Chapter  Gender  Nobility  \
# name
# ...

# %%
battle1
# Out:
#                                                     year  battle_number  \
# name
# Battle of the Golden Tooth                           298              1
# Battle at the Mummer's Ford                          298              2
# Battle of Riverrun                                   298              3
# Battle of the Green Fork                             298              4
# Battle of the Whispering Wood                        298              5
# Battle of the Camps                                  298              6
# Sack of Darry                                        298              7
# Battle of Moat Cailin                                299              8
# Battle of Deepwood Motte                             299              9
# Battle of the Stony Shore                            299             10
# Battle of Torrhen's Square                           299             11
# Battle of Winterfell                                 299             12
# ...

# %%
battle2 = battle1.year.value_counts()

# %%
death2 = death1['Death Year'].value_counts()

# %%
death2.index = death2.index.astype(int)

# %%
death2
# Out:
# 299    156
# 300    100
# 298     46
# 297      3
# Name: Death Year, dtype: int64

# %%
battle2
# Out:
# 299    20
# 300    11
# 298     7
# Name: year, dtype: int64

# %%
death2
# Out:
# 299    156
# 300    100
# 298     46
# 297      3
# Name: Death Year, dtype: int64

# %%
battle2.values
# Out:
# array([20, 11,  7], dtype=int64)

# %%
battle_death = pd.DataFrame(death2)

# %%
battle_death
# Out:
#      Death Year
# 299         156
# 300         100
# 298          46
# 297           3

# %%
battle_death2 = pd.DataFrame(battle2)

# %%
battle_death2
# Out:
#      year
# 299    20
# 300    11
# 298     7

# %%
battle_death.concat(battle_death2)

# %%
battle_death = pd.concat([battle_death, battle_death2], axis = 1)

# %%
battle_death
# Out:
#      Death Year  year
# 297           3   NaN
# 298          46   7.0
# 299         156  20.0
# 300         100  11.0

# %%
battle_death.columns = ['사망자수', '전쟁횟수']

# %%
battle_death
# Out:
#      사망자수  전쟁횟수
# 297     3   NaN
# 298    46   7.0
# 299   156  20.0
# 300   100  11.0

# %%
battle_death.plot( xlabel = '전투가일어난년도')
# Out:
# <AxesSubplot:xlabel='전투가일어난년도'>

# %%
############################# 강사님 풀이 ##############################

# %%
#1. 년도별 사망자수 구하기
death_for_year = death['Death Year'].value_counts().sort_index()

# %%
#2. 년도별 전쟁횟수 구하기
battles.year.value_counts()
# Out:
# 299    20
# 300    11
# 298     7
# Name: year, dtype: int64

# %%
battle_for_year = battles.pivot_table(index = 'year', aggfunc = 'count', values = 'name')

# %%
battle_for_year
# Out:
#       name
# year
# 298      7
# 299     20
# 300     11

# %%
type(battle_for_year)
# Out:
# pandas.core.frame.DataFrame

# %%
death_for_year
# Out:
# 297.0      3
# 298.0     46
# 299.0    156
# 300.0    100
# Name: Death Year, dtype: int64

# %%
#3. 두 분석결과를 하나의 데이터 프레임으로 합치기

# %%
death_for_year
# Out:
# 297.0      3
# 298.0     46
# 299.0    156
# 300.0    100
# Name: Death Year, dtype: int64

# %%
battle_for_year
# Out:
#       name
# year
# 298      7
# 299     20
# 300     11

# %%
data = pd.concat([death_for_year, battle_for_year], axis=1)

# %%
data.columns = ['# of death', '# of battles']

# %%
data
# Out:
#        # of death  # of battles
# 297.0           3           NaN
# 298.0          46           7.0
# 299.0         156          20.0
# 300.0         100          11.0

# %%
data.fillna(0, inplace = True)

# %%
data.plot(figsize = (5,3), title = '년도별 사망자와 전쟁횟수 추이', xticks = data.index,
         xlabel = '년도',
         ylabel = '횟수')
# Out:
# <AxesSubplot:title={'center':'년도별 사망자와 전쟁횟수 추이'}, xlabel='년도', ylabel='횟수'>

# %%
data.corr()
# Out:
#               # of death  # of battles
# # of death       1.00000       0.98991
# # of battles     0.98991       1.00000
